# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def putAsMatrix(data, length):
 X, Y =[], []
 for i in range(len(data)-length):
  d=i+length  
  X.append(data[i:d,])
  Y.append(data[d,])
 return np.array(X), np.array(Y)

N = 5000    
Tp = 800    

t=np.arange(0,N)
x=(np.sin(0.02*t)+2*np.random.rand(N))*(t/N)
df = pd.DataFrame(x)
df.head()

plt.plot(df)
plt.title('Formula Model')
plt.show()

training_scores = []
for length in range(4, 21):

    values=df.values
    train,test = values[0:Tp,:], values[Tp:N,:]

    # add length elements into train and test
    test = np.append(test,np.repeat(test[-1,],length))
    train = np.append(train,np.repeat(train[-1,],length))

    trainX,trainY =putAsMatrix(train,length)
    testX,testY =putAsMatrix(test,length)
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))


    model = Sequential()
    #Include here the specification of your network
    #**********************************************
    #model.add(...)
    #...
    #**********************************************
    model.add(Dense(200, activation='relu'))
    model.add(Dense(500, activation='relu'))
    model.add(Dense(1000, activation='relu'))
    model.add(Dense(500, activation='relu'))
    model.add(Dense(50, activation='softmax'))

    model.compile(loss='mean_squared_error', optimizer='rmsprop')
    model.fit(trainX,trainY, epochs=50, batch_size=16, verbose=0)
    model.summary()

    trainPredict = model.predict(trainX)
    testPredict= model.predict(testX)
    predicted=np.concatenate((trainPredict[:,0,:],testPredict[:,0,:]),axis=0)

    trainScore = model.evaluate(trainX, trainY, verbose=0)
    print(trainScore)
    training_scores.append(trainScore)

    #the vertical red line shows the point where testing data starts
    index = df.index.values
    plt.plot(index,df)
    plt.plot(index,predicted)
    plt.axvline(df.index[Tp], c="r")
    title = ('Trained Model (Length = ' + str(length) + ')')
    plt.title(title)
    plt.show()
    
plt.clf()
plt.plot(range(4, 21), training_scores)
plt.xlabel('Length')
plt.ylabel('Training Score')
plt.show()
# Out:
# Model: "sequential_92"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_344 (Dense)            multiple                  1000
# _________________________________________________________________
# dense_345 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_346 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_347 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_348 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,128,050
# Trainable params: 1,128,050
# Non-trainable params: 0
# _________________________________________________________________
# 0.014458409433136693
# Model: "sequential_93"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_349 (Dense)            multiple                  1200
# _________________________________________________________________
# dense_350 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_351 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_352 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_353 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,128,250
# Trainable params: 1,128,250
# Non-trainable params: 0
# _________________________________________________________________
# 0.01445962603611406
# Model: "sequential_94"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_354 (Dense)            multiple                  1400
# _________________________________________________________________
# dense_355 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_356 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_357 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_358 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,128,450
# Trainable params: 1,128,450
# Non-trainable params: 0
# _________________________________________________________________
# 0.014460782160167582
# Model: "sequential_95"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_359 (Dense)            multiple                  1600
# _________________________________________________________________
# dense_360 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_361 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_362 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_363 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,128,650
# Trainable params: 1,128,650
# Non-trainable params: 0
# _________________________________________________________________
# 0.014462012518051778
# Model: "sequential_96"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_364 (Dense)            multiple                  1800
# _________________________________________________________________
# dense_365 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_366 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_367 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_368 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,128,850
# Trainable params: 1,128,850
# Non-trainable params: 0
# _________________________________________________________________
# 0.014463267473038286
# Model: "sequential_97"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_369 (Dense)            multiple                  2000
# _________________________________________________________________
# dense_370 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_371 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_372 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_373 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,129,050
# Trainable params: 1,129,050
# Non-trainable params: 0
# _________________________________________________________________
# 0.014464427161001367
# Model: "sequential_98"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_374 (Dense)            multiple                  2200
# _________________________________________________________________
# dense_375 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_376 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_377 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_378 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,129,250
# Trainable params: 1,129,250
# Non-trainable params: 0
# _________________________________________________________________
# 0.014465586835576687
# Model: "sequential_99"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_379 (Dense)            multiple                  2400
# _________________________________________________________________
# dense_380 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_381 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_382 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_383 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,129,450
# Trainable params: 1,129,450
# Non-trainable params: 0
# _________________________________________________________________
# 0.014466913904616376
# Model: "sequential_100"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_384 (Dense)            multiple                  2600
# _________________________________________________________________
# dense_385 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_386 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_387 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_388 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,129,650
# Trainable params: 1,129,650
# Non-trainable params: 0
# _________________________________________________________________
# 0.014468255184037843
# Model: "sequential_101"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_389 (Dense)            multiple                  2800
# _________________________________________________________________
# dense_390 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_391 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_392 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_393 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,129,850
# Trainable params: 1,129,850
# Non-trainable params: 0
# _________________________________________________________________
# 0.014469616319256601
# Model: "sequential_102"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_394 (Dense)            multiple                  3000
# _________________________________________________________________
# dense_395 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_396 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_397 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_398 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,130,050
# Trainable params: 1,130,050
# Non-trainable params: 0
# _________________________________________________________________
# 0.014470827549666864
# Model: "sequential_103"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_399 (Dense)            multiple                  3200
# _________________________________________________________________
# dense_400 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_401 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_402 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_403 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,130,250
# Trainable params: 1,130,250
# Non-trainable params: 0
# _________________________________________________________________
# 0.014472223361663055
# Model: "sequential_104"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_404 (Dense)            multiple                  3400
# _________________________________________________________________
# dense_405 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_406 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_407 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_408 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,130,450
# Trainable params: 1,130,450
# Non-trainable params: 0
# _________________________________________________________________
# 0.014473427413322497
# Model: "sequential_105"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_409 (Dense)            multiple                  3600
# _________________________________________________________________
# dense_410 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_411 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_412 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_413 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,130,650
# Trainable params: 1,130,650
# Non-trainable params: 0
# _________________________________________________________________
# 0.014474702017323579
# Model: "sequential_106"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_414 (Dense)            multiple                  3800
# _________________________________________________________________
# dense_415 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_416 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_417 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_418 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,130,850
# Trainable params: 1,130,850
# Non-trainable params: 0
# _________________________________________________________________
# 0.014476066476199777
# Model: "sequential_107"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_419 (Dense)            multiple                  4000
# _________________________________________________________________
# dense_420 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_421 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_422 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_423 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,131,050
# Trainable params: 1,131,050
# Non-trainable params: 0
# _________________________________________________________________
# 0.014477511918521487
# Model: "sequential_108"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_424 (Dense)            multiple                  4200
# _________________________________________________________________
# dense_425 (Dense)            multiple                  100500
# _________________________________________________________________
# dense_426 (Dense)            multiple                  501000
# _________________________________________________________________
# dense_427 (Dense)            multiple                  500500
# _________________________________________________________________
# dense_428 (Dense)            multiple                  25050
# =================================================================
# Total params: 1,131,250
# Trainable params: 1,131,250
# Non-trainable params: 0
# _________________________________________________________________
# 0.014478739644109737

# %% [markdown]
# The length variable appears to increase the training score as it is increased in a mostly linear form. The architecture of for this particular application seems to have a small level of variability.
